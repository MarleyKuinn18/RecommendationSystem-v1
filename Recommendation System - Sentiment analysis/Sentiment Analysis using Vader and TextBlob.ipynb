# %%
import numpy as np
import pandas as pd
import nltk
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
import re
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from textblob import TextBlob
from sklearn.metrics import f1_score, accuracy_score
from tqdm import tqdm
from textblob.sentiments import NaiveBayesAnalyzer
import nltk

# %%
import os
os.chdir(os.getcwd())

# %%
import pytreebank
import sys

dataset = pytreebank.load_sst()

# %%
out_path = os.path.join(sys.path[0], 'sst_{}.txt')
for category in ['train', 'test', 'dev']:
    with open(out_path.format(category), 'w') as outfile:
        for item in dataset[category]:
            outfile.write("__label__{}\t{}\n".format(
                item.to_labeled_lines()[0][0] + 1,
                item.to_labeled_lines()[0][1]
            ))

# %%
train = pd.read_csv('sst_train.txt', sep='\t',header=None, names=['sentiment_label', 'sentence'])
train.head()
# Out:
#   sentiment_label                                           sentence
# 0      __label__4  The Rock is destined to be the 21st Century 's...
# 1      __label__5  The gorgeously elaborate continuation of `` Th...
# 2      __label__4  Singer/composer Bryan Adams contributes a slew...
# 3      __label__3  You 'd think by now America would have had eno...
# 4      __label__4               Yet the act is still charming here .

# %% [markdown]
# ### Train Model

# %%
def textblob_score(sentence):
    return TextBlob(sentence).sentiment.polarity

# %%
train['textblob_score'] = train['sentence'].apply(textblob_score)
train['textblob_pred'] = pd.cut(train['textblob_score'], bins=5, labels=[1, 2, 3, 4, 5])
train = train.drop('textblob_score', axis=1)
train.head()
# Out:
#   sentiment_label                                           sentence  \
# 0      __label__4  The Rock is destined to be the 21st Century 's...
# 1      __label__5  The gorgeously elaborate continuation of `` Th...
# 2      __label__4  Singer/composer Bryan Adams contributes a slew...
# 3      __label__3  You 'd think by now America would have had eno...
# 4      __label__4               Yet the act is still charming here .
#
#   textblob_pred
# 0             4
# 1             4
# 2             3
# 3             3
# 4             5

# %%
data = pd.read_csv('Amazon Book Reviews.csv')
data.head()
# Out:
#        reviewerID      asin     Title       reviewerName helpful  \
# 0  A15Q7ABIU9O9YZ  60554800  Red Tide  Larry Scantlebury   [2,3]
# 1   AUIJDXNYVTEA8  60554800  Red Tide       Les Stockton   [0,2]
# 2  A20N5GOON55TE9  60554800  Red Tide               lila   [0,2]
# 3  A1CT8ENDZSYTX3  60554800  Red Tide            Lisa B.   [1,2]
# 4  A2SI6BNK5SWSMD  60554800  Red Tide      L. J. Roberts   [2,2]
#
#                                           reviewText  overall  \
# 0  This is my first GM Ford book and I will read ...        3
# 1  I liked the story.  I thought the book added a...        4
# 2  As always, G.M. Ford does not disappoint. I st...        5
# 3  I love Ford's Leo Waterman series and the firs...        3
# 4  It was nice to see Corso working with the poli...        3
#
#                             summary  unixReviewTime   reviewTime
# 0  Let's keep it real, not personal      1127606400  09 25, 2005
# 1                        I liked it      1361923200  02 27, 2013
# 2                      Good reading      1366761600  04 24, 2013
# 3       Science Fiction or Mystery?      1122249600  07 25, 2005
# 4  3.5 stars - Needed a better end.      1113004800   04 9, 2005

# %%
reviews = list(data['reviewText'])

# %%
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

# %%
tokenizer = RegexpTokenizer(r'\w+')
nltk.download('stopwords')
en_stopwords = set(stopwords.words('english'))
ps = nltk.stem.RSLPStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def getCleanComment(review):
    review = str(review)
    review = review.lower()
    review = review.replace('"','')
    review = review.replace(';','')
    review = review.replace('_','')
    review = review.replace('-','')
    review = review.replace(',','')
    review = re.sub('\d', '', review)
    tokens = tokenizer.tokenize(review)
    new_tokens = [i for i in tokens if i not in en_stopwords]
    stemmed_tokens = [ps.stem(i) for i in new_tokens]
    
    cleaned_review = ' '.join(stemmed_tokens)
    return cleaned_review

# %%
preprocessed_reviews = [getCleanComment(i) for i in reviews]

# %%
data['preprocessed_reviews'] = preprocessed_reviews
data['textblob_score'] = data["preprocessed_reviews"].apply(textblob_score)
data['textblob_pred'] = pd.cut(data['textblob_score'], bins=5, labels=[1, 2, 3, 4, 5])
data.head(n=10)
# Out:
#        reviewerID      asin     Title                       reviewerName  \
# 0  A15Q7ABIU9O9YZ  60554800  Red Tide                  Larry Scantlebury
# 1   AUIJDXNYVTEA8  60554800  Red Tide                       Les Stockton
# 2  A20N5GOON55TE9  60554800  Red Tide                               lila
# 3  A1CT8ENDZSYTX3  60554800  Red Tide                            Lisa B.
# 4  A2SI6BNK5SWSMD  60554800  Red Tide                      L. J. Roberts
# 5  A1SSYYL2WTAK4Y  60554800  Red Tide                            Mtnhi 5
# 6   AVZ1LIW6EUQIK  60554800  Red Tide        Robert J. Unger "Dr. Gates"
# 7  A3QJQQZTKFV7BJ  60554800  Red Tide                     Sandy "WR Gma"
# 8  A3OMPCA27U6WL2  60554800  Red Tide                        Teri Tipton
# 9  A31WHFXF6T06DR  60554800  Red Tide  Watson McFestus "Watson McFestus"
#
#   helpful                                         reviewText  overall  \
# 0   [2,3]  This is my first GM Ford book and I will read ...        3
# 1   [0,2]  I liked the story.  I thought the book added a...        4
# 2   [0,2]  As always, G.M. Ford does not disappoint. I st...        5
# 3   [1,2]  I love Ford's Leo Waterman series and the firs...        3
# 4   [2,2]  It was nice to see Corso working with the poli...        3
# 5   [0,0]  Bet you can't put this one down. Ford's writin...        5
# 6   [0,2]  I started with his first books and have now re...        5
# 7   [1,1]  I was worried through almost the first half of...        3
# 8   [2,2]  I really enjoy G.M. Ford's writing.  I love hi...        2
# 9   [0,2]  Sort of a medical thriller - which is a type o...        4
#
#                                              summary  unixReviewTime  \
# 0                   Let's keep it real, not personal      1127606400
# 1                                         I liked it      1361923200
# 2                                       Good reading      1366761600
# 3                        Science Fiction or Mystery?      1122249600
# 4                   3.5 stars - Needed a better end.      1113004800
# 5                                          Excellent      1397952000
# 6                            All his books are great      1359849600
# 7  I'm still a loyal reader, but this series seem...      1373241600
# 8         I'm...Trying....To.....Finish......It.....      1169251200
# 9                              Pretty good 3.5 stars      1360713600
#
#     reviewTime                               preprocessed_reviews  \
# 0  09 25, 2005  first gm ford book read well written mysteryad...
# 1  02 27, 2013  liked story thought book added bit much leftle...
# 2  04 24, 2013  alway g ford disappoint still lik leo waterman...
# 3  07 25, 2005  lov ford leo waterman seri first frank cors st...
# 4   04 9, 2005  nic see cors working polic chang coupl good ch...
# 5  04 20, 2014  bet put one ford writing excellentexciting poi...
# 6   02 3, 2013  started first book read everyon recommend star...
# 7   07 8, 2013  worried almost first half book fearing ford de...
# 8  01 20, 2007  really enjoy g ford writing lov charact lov se...
# 9  02 13, 2013  sort medic thrill typ thrill usually lik cors ...
#
#    textblob_score textblob_pred
# 0        0.030049             3
# 1        0.600000             4
# 2        1.000000             5
# 3        0.051190             3
# 4        0.080000             3
# 5        0.000000             3
# 6        0.246667             4
# 7        0.093981             3
# 8        0.117980             3
# 9        0.287500             4

# %% [markdown]
# ### Using Vader

# %%
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...

# %%
data['vader_score'] = data["preprocessed_reviews"].apply(lambda Description: sid.polarity_scores(Description))
data.head()
# Out:
#        reviewerID      asin     Title       reviewerName helpful  \
# 0  A15Q7ABIU9O9YZ  60554800  Red Tide  Larry Scantlebury   [2,3]
# 1   AUIJDXNYVTEA8  60554800  Red Tide       Les Stockton   [0,2]
# 2  A20N5GOON55TE9  60554800  Red Tide               lila   [0,2]
# 3  A1CT8ENDZSYTX3  60554800  Red Tide            Lisa B.   [1,2]
# 4  A2SI6BNK5SWSMD  60554800  Red Tide      L. J. Roberts   [2,2]
#
#                                           reviewText  overall  \
# 0  This is my first GM Ford book and I will read ...        3
# 1  I liked the story.  I thought the book added a...        4
# 2  As always, G.M. Ford does not disappoint. I st...        5
# 3  I love Ford's Leo Waterman series and the firs...        3
# 4  It was nice to see Corso working with the poli...        3
#
#                             summary  unixReviewTime   reviewTime  \
# 0  Let's keep it real, not personal      1127606400  09 25, 2005
# 1                        I liked it      1361923200  02 27, 2013
# 2                      Good reading      1366761600  04 24, 2013
# 3       Science Fiction or Mystery?      1122249600  07 25, 2005
# 4  3.5 stars - Needed a better end.      1113004800   04 9, 2005
#
#                                 preprocessed_reviews  textblob_score  \
# 0  first gm ford book read well written mysteryad...        0.030049
# 1  liked story thought book added bit much leftle...        0.600000
# 2  alway g ford disappoint still lik leo waterman...        1.000000
# 3  lov ford leo waterman seri first frank cors st...        0.051190
# 4  nic see cors working polic chang coupl good ch...        0.080000
#
#   textblob_pred                                        vader_score
# 0             3  {'neg': 0.134, 'neu': 0.71, 'pos': 0.156, 'com...
# 1             4  {'neg': 0.0, 'neu': 0.592, 'pos': 0.408, 'comp...
# 2             5  {'neg': 0.151, 'neu': 0.615, 'pos': 0.235, 'co...
# 3             3  {'neg': 0.057, 'neu': 0.876, 'pos': 0.066, 'co...
# 4             3  {'neg': 0.085, 'neu': 0.769, 'pos': 0.146, 'co...

# %%
data['compound'] = data['vader_score'].apply(lambda score_dict: score_dict['compound'])
data['vader_pred'] = pd.cut(data['compound'], bins=5, labels=[1, 2, 3, 4, 5])
data.tail(n=10)
# Out:
#           reviewerID      asin                                Title  \
# 7426   ALAAIPGIFF98F  60582006  A Good Yarn (Blossom Street, No. 2)
# 7427   AH7CBIWDTHXWA  60582006  A Good Yarn (Blossom Street, No. 2)
# 7428  A3MLDUWII68NKB  60582006  A Good Yarn (Blossom Street, No. 2)
# 7429  A3GWM1FHA3EQPM  60582006  A Good Yarn (Blossom Street, No. 2)
# 7430  A1XJNL666U1E16  60582006  A Good Yarn (Blossom Street, No. 2)
# 7431  A27D52RUOADQVR  60582006  A Good Yarn (Blossom Street, No. 2)
# 7432   A93B8XMH93D1R  60582006  A Good Yarn (Blossom Street, No. 2)
# 7433  A2JEMVYOM5IFU0  60582006  A Good Yarn (Blossom Street, No. 2)
# 7434   AX64AMAD1RTMI  60582006  A Good Yarn (Blossom Street, No. 2)
# 7435  A1Y0Y74B0POAA6  60582006  A Good Yarn (Blossom Street, No. 2)
#
#                      reviewerName  helpful  \
# 7426                           LH    [1,2]
# 7427                    Lois Lain    [3,3]
# 7428          Lorraine Janice Lee    [0,0]
# 7429          Marianne O. Schmidt    [8,8]
# 7430                      Melissa    [0,0]
# 7431                        Mikew    [0,0]
# 7432  miss demeaner "BOOK SMARTS"   [5,13]
# 7433            Norah E. Sempelsz    [0,0]
# 7434                   Robin Wren    [0,0]
# 7435       Sharon Galligar Chance  [54,57]
#
#                                              reviewText  overall  \
# 7426  If you are a knitter, you will enjoy reading t...        4
# 7427  I have to admit I feel a little nerdy reading ...        4
# 7428  Never thought I'd see this. Good story, but I ...        4
# 7429  I love all of Debbie's books - they are sweet,...        5
# 7430  Always great to read Debbie!  She lets you esc...        5
# 7431  Love getting to know each of their lives. She ...        5
# 7432  UNLIKE SOME OF REVIEWERS ON HERE, I WON'T END ...        2
# 7433  I could not put this book down, I was so mired...        5
# 7434  I have read Debbie Macomber's "The Shop on Blo...        4
# 7435  There's something so soothing about knitting -...        5
#
#                              summary  unixReviewTime   reviewTime  \
# 7426         An easy, feel good read      1163030400   11 9, 2006
# 7427                     A Good Book      1129334400  10 15, 2005
# 7428            Books about knitting      1383264000   11 1, 2013
# 7429            Debbie Does It Again      1130630400  10 30, 2005
# 7430        Another feel good story!      1364860800   04 2, 2013
# 7431                    Heartwarming      1362268800   03 3, 2013
# 7432                   A  LONG  YARN      1149811200   06 9, 2006
# 7433     Warm and Inviting Yarn Shop      1203811200  02 24, 2008
# 7434  Just a warm and touching Story      1186444800   08 7, 2007
# 7435  A treasure! Very heartwarming!      1114732800  04 29, 2005
#
#                                    preprocessed_reviews  textblob_score  \
# 7426  knitt enjoy reading light story knitting shop ...        0.400000
# 7427  admit feel littl nerdy reading novel set yarn ...        0.140000
# 7428  nev thought see good story read shop blossom s...        0.611111
# 7429  lov debbi book sweet almost alway happy ending...        0.432386
# 7430  alway great read debbi let escap nuanc lif ano...        0.400000
# 7431  lov getting know liv creat charact mind help b...        0.000000
# 7432  unlik review end typing ent chapt opinion get ...        0.321667
# 7433  could put book mired liv peopl visit blossom s...        0.125000
# 7434  read debbi macomb shop blossom street thought ...        0.421157
# 7435  something soothing knitting sweet clicking nee...        0.299351
#
#      textblob_pred                                        vader_score  \
# 7426             4  {'neg': 0.0, 'neu': 0.758, 'pos': 0.242, 'comp...
# 7427             3  {'neg': 0.064, 'neu': 0.756, 'pos': 0.18, 'com...
# 7428             5  {'neg': 0.0, 'neu': 0.613, 'pos': 0.387, 'comp...
# 7429             4  {'neg': 0.013, 'neu': 0.665, 'pos': 0.322, 'co...
# 7430             4  {'neg': 0.0, 'neu': 0.709, 'pos': 0.291, 'comp...
# 7431             3  {'neg': 0.0, 'neu': 0.787, 'pos': 0.213, 'comp...
# 7432             4  {'neg': 0.049, 'neu': 0.694, 'pos': 0.257, 'co...
# 7433             3  {'neg': 0.0, 'neu': 0.863, 'pos': 0.137, 'comp...
# 7434             4  {'neg': 0.04, 'neu': 0.661, 'pos': 0.299, 'com...
# 7435             4  {'neg': 0.043, 'neu': 0.728, 'pos': 0.229, 'co...
#
#       compound vader_pred
# 7426    0.4939          4
# 7427    0.7184          5
# 7428    0.9001          5
# 7429    0.9980          5
# 7430    0.8481          5
# 7431    0.4019          4
# 7432    0.9682          5
# 7433    0.6908          5
# 7434    0.9493          5
# 7435    0.9982          5
